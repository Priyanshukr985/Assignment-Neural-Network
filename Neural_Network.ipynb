# %% [markdown]
# **Question 1: What is Deep Learning? Briefly describe how it evolved and how it differs
# from traditional machine learning**
#
# Ans : ***Deep Learning is a subfield of Machine Learning that uses deep (multi-layered) artificial neural networks to learn complex patterns from large datasets. It mimics the working of the human brain to automatically extract features and make predictions.***
#
# *Evolution of Deep Learning*
#
# 1. Originated from artificial neural networks and the perceptron model.
#
# 2. Development of backpropagation algorithm enabled training of multi-layer networks.
#
# 3. Limited progress earlier due to lack of data and computational power.
#
# 4. Rapid growth in recent years due to big data, high-performance GPUs, and improved algorithms.
#
# *Difference from Traditional Machine Learning*
#
# 1. Traditional ML requires manual feature engineering, while Deep Learning automatically learns features.
#
# 2. Deep Learning uses multiple hidden layers, whereas traditional ML uses shallow models.
#
# 3. Deep Learning performs better on complex and unstructured data like images, speech, and text.
#
# *Conclusion:*
# Deep Learning is more powerful than traditional machine learning for complex tasks due to its deep architecture and automatic feature learning capability.

# %% [markdown]
# **Question 2: Explain the basic architecture and functioning of a Perceptron. What are its
# limitations?**
#
# Ans: **Perceptron is the simplest form of an artificial neural network used for binary classification. It is a single-layer, feed-forward model inspired by the functioning of a biological neuron.**
#
# *Basic Architecture of a Perceptron*
#
# A perceptron consists of:
#
# 1. Input layer: Inputs x1 , x2 , .....,xn
#
#
# 2. Weights: w1 , w2 , .... , wn associated with each input
#
# 3. Bias:  b to shift the decision boundary
#
# 4. Summation unit: Computes weighted sum
#
#
# 5. Activation function: Usually a step (threshold) function that produces binary output (0 or 1)
#
# **Functioning of a Perceptron**
#
# 1. Inputs are multiplied by corresponding weights.
#
# 2. The weighted inputs are summed along with bias.
#
# 3. The result is passed through the activation function.
#
# 4. Output is generated based on the threshold.
#
# During training, weights are updated using the Perceptron Learning Rule to minimize classification errors.
#
# **Limitations of a Perceptron**
#
# 1. Can classify only linearly separable data.
#
# 2. Cannot solve problems like XOR.
#
# 3. Uses a single layer, so it cannot learn complex patterns.
#
# 4. Limited to binary classification.
#
# 5. Not suitable for real-world complex tasks.
#
# *Conclusion:*
#
# The perceptron is a foundational neural network model but has limited learning capability due to its single-layer structure and linear decision boundary.

# %% [markdown]
# **Question 3: Describe the purpose of activation function in neural networks. Compare
# Sigmoid, ReLU, and Tanh functions.**
#
# Ans: **Activation Function**
#
# Purpose of Activation Function
#
# **An activation function introduces non-linearity into a neural network. Without activation functions, a neural network would behave like a linear model, regardless of the number of layers. Activation functions enable the network to:**
#
# 1. Learn complex and non-linear relationships
#
# 2. Decide whether a neuron should be activated or not
#
# 3. Improve the model’s representational power
#
#
# Comparison of Sigmoid, Tanh, and ReLU
#
# ![WhatsApp Image 2026-01-08 at 6.23.39 PM.jpeg](data:image/jpeg;base64,...)
#
#
#
#
# **Conclusion**
#
# Activation functions are essential for enabling neural networks to model non-linear patterns. Sigmoid and Tanh are traditional functions but suffer from vanishing gradients, while ReLU is widely used in deep learning due to its simplicity and efficiency.

# %% [markdown]
# **Question 4: What is the difference between Loss function and Cost function in neural
# networks? Provide examples.**
#
# Ans:

# %%
'''Question 4: Difference between Loss Function and Cost Function

Loss Function:
A loss function measures the error for a single training example by comparing
the predicted output with the actual output. It tells how wrong the prediction
is for one data point.

Example:
Mean Squared Error (for one sample):
L = (y - ŷ)²

Binary Cross Entropy Loss:
L = −[y log(ŷ) + (1 − y) log(1 − ŷ)]


Cost Function:
A cost function is the average (or total) loss over the entire training dataset.
It represents the overall performance of the neural network and is minimized
during training.

Example:
Mean Squared Error Cost Function:
J = (1/n) Σ (yᵢ − ŷᵢ)²


Difference:

Loss Function:
• Calculated for a single data point
• Measures individual prediction error

Cost Function:
• Calculated over the entire dataset
• Measures overall model performance


Conclusion:
Loss function evaluates error for one training example, whereas cost function
combines all losses to guide the optimization of the neural network.'''

# %% [markdown]
# **Question 5: What is the role of optimizers in neural networks? Compare Gradient
# Descent, Adam, and RMSprop.**

# %%
'''Ans :-

Role of Optimizers in Neural Networks

Optimizers are algorithms used to update the weights and biases of a neural
network in order to minimize the loss or cost function. They control how the
model learns by adjusting parameters using gradients during training.

Role of Optimizers:
• Minimize the loss function
• Update weights and biases efficiently
• Improve convergence speed
• Help reach the optimal solution


Comparison of Gradient Descent, Adam, and RMSprop

Gradient Descent:
• Updates weights using the average gradient of the entire dataset
• Uses a fixed learning rate
• Simple and stable
• Slow for large datasets

Update rule:
w = w − η ∇J(w)


RMSprop:
• Uses adaptive learning rate
• Maintains moving average of squared gradients
• Reduces oscillations during training
• Works well for non-stationary problems

Update rule:
w = w − η / √(E[g²] + ε) * g


Adam (Adaptive Moment Estimation):
• Combines Momentum and RMSprop
• Uses first and second moment of gradients
• Fast convergence
• Widely used in deep learning

Update rule:
mₜ = β₁ mₜ₋₁ + (1 − β₁) g
vₜ = β₂ vₜ₋₁ + (1 − β₂) g²
w = w − η mₜ / √(vₜ + ε)


Difference Summary:

Gradient Descent:
• Fixed learning rate
• Slow convergence
• Simple implementation

RMSprop:
• Adaptive learning rate
• Faster than Gradient Descent
• Handles oscillations well

Adam:
• Adaptive learning rate
• Very fast convergence
• Best for deep neural networks


Conclusion:
Optimizers play a crucial role in neural networks by efficiently minimizing the
loss function. Adam is generally preferred due to its speed and stability.'''

# %%
'''Question 6: Write a Python program to implement a single-layer perceptron from
scratch using NumPy to solve the logical AND gate.'''


# Single Layer Perceptron for AND Gate
# Using NumPy

import numpy as np
import matplotlib.pyplot as plt

# AND gate input and output
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([0, 0, 0, 1])  # AND gate output

# Initialize weights and bias
weights = np.zeros(X.shape[1])
bias = 0
learning_rate = 0.1
epochs = 20

# Step activation function
def step_function(z):
    return 1 if z >= 0 else 0

# Training the perceptron
for epoch in range(epochs):
    print(f"Epoch {epoch+1}")
    for i in range(len(X)):
        linear_output = np.dot(X[i], weights) + bias
        y_pred = step_function(linear_output)

        # Perceptron update rule
        error = y[i] - y_pred
        weights = weights + learning_rate * error * X[i]
        bias = bias + learning_rate * error

        print(f"Input: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}")
    print("Weights:", weights, "Bias:", bias)
    print("-" * 40)

# Testing the trained perceptron
print("\nTesting AND Gate:")
for i in range(len(X)):
    output = step_function(np.dot(X[i], weights) + bias)
    print(f"Input: {X[i]} -> Output: {output}")
# Out:
# Epoch 1
# Input: [0 0], Predicted: 1, Actual: 0
# Input: [0 1], Predicted: 0, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# Input: [1 1], Predicted: 0, Actual: 1
# Weights: [0.1 0.1] Bias: 0.0
# ----------------------------------------
# Epoch 2
# Input: [0 0], Predicted: 1, Actual: 0
# Input: [0 1], Predicted: 1, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# Input: [1 1], Predicted: 0, Actual: 1
# Weights: [0.2 0.1] Bias: -0.1
# ----------------------------------------
# Epoch 3
# Input: [0 0], Predicted: 0, Actual: 0
# Input: [0 1], Predicted: 1, Actual: 0
# Input: [1 0], Predicted: 1, Actual: 0
# Input: [1 1], Predicted: 0, Actual: 1
# Weights: [0.2 0.1] Bias: -0.20000000000000004
# ----------------------------------------
# Epoch 4
# Input: [0 0], Predicted: 0, Actual: 0
# Input: [0 1], Predicted: 0, Actual: 0
# Input: [1 0], Predicted: 0, Actual: 0
# Input: [1 1], Predicted: 1, Actual: 1
# Weights: [0.2 0.1] Bias: -0.20000000000000004
# ...

# %%
'''Question 7: Implement and visualize Sigmoid, ReLU, and Tanh activation functions
using Matplotlib.'''


import numpy as np
import matplotlib.pyplot as plt

# Input values
x = np.linspace(-10, 10, 400)

# Activation functions
sigmoid = 1 / (1 + np.exp(-x))     # tf.keras.activations.sigmoid
relu = np.maximum(0, x)            # tf.keras.activations.relu
tanh = np.tanh(x)                  # tf.keras.activations.tanh

# Plotting activation functions
plt.figure()
plt.plot(x, sigmoid, label="Sigmoid")
plt.plot(x, relu, label="ReLU")
plt.plot(x, tanh, label="Tanh")
plt.xlabel("Input")
plt.ylabel("Output")
plt.title("Activation Functions")
plt.legend()
plt.show()

# %%
'''Question 8: Use Keras to build and train a simple multilayer neural network on the
MNIST digits dataset. Print the training accuracy'''

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize the data
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the multilayer neural network
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=32,
    verbose=1
)

# Print training accuracy
training_accuracy = history.history['accuracy'][-1]
print("Training Accuracy:", training_accuracy)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8794 - loss: 0.4206
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9656 - loss: 0.1151
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9775 - loss: 0.0718
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9843 - loss: 0.0505
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9868 - loss: 0.0408
# Training Accuracy: 0.9858499765396118

# %%
'''Question 9: Visualize the loss and accuracy curves for a neural network model trained
on the Fashion MNIST dataset. Interpret the training behavior.'''

import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical

# Load Fashion MNIST dataset
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Normalize the data
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the neural network
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Plot Loss curve
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.show()

# Plot Accuracy curve
plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.show()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.7800 - loss: 0.6232 - val_accuracy: 0.8516 - val_loss: 0.4226
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8635 - loss: 0.3766 - val_accuracy: 0.8501 - val_loss: 0.4085
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8782 - loss: 0.3287 - val_accuracy: 0.8610 - val_loss: 0.3979
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8842 - loss: 0.3148 - val_accuracy: 0.8757 - val_loss: 0.3522
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8940 - loss: 0.2883 - val_accuracy: 0.8714 - val_loss: 0.3584
# Epoch 6/10
# ...

# %%
'''Question 10: You are working on a project for a bank that wants to automatically detect
fraudulent transactions. The dataset is large, imbalanced, and contains structured
features like transaction amount, merchant ID, and customer location. The goal is to
classify each transaction as fraudulent or legitimate.
Explain your real-time data science workflow:
● How would you design a deep learning model (perceptron or multilayer NN)?
● Which activation function and loss function would you use, and why?
● How would you train and evaluate the model, considering class imbalance?
● Which optimizer would be suitable, and how would you prevent overfitting?'''

#  Real-Time Data Science Workflow for Fraud Detection

# The objective is to automatically classify bank transactions as fraudulent or
# legitimate using a large, imbalanced dataset with structured features such as
# transaction amount, merchant ID, and customer location.

# Model Design:
# A single-layer perceptron is not suitable for this problem because fraud
# patterns are complex and non-linear. Therefore, a Multilayer Neural Network
# (MLP) is preferred. The model consists of an input layer representing
# transaction features, two or three hidden dense layers to learn complex
# patterns, and a single neuron in the output layer for binary classification.

# Activation and Loss Functions:
# ReLU activation function is used in the hidden layers because it enables faster
# training and reduces the vanishing gradient problem. Sigmoid activation is used
# in the output layer as it produces a probability value between 0 and 1, which
# is suitable for fraud detection. Binary Cross-Entropy loss function is chosen
# since it is ideal for binary classification tasks and penalizes incorrect
# predictions effectively.

# Training and Evaluation (Handling Class Imbalance):
# The dataset is highly imbalanced, with very few fraudulent transactions.
# To handle this imbalance, class weights are used to give higher importance to
# fraud cases. Oversampling techniques such as SMOTE or undersampling can also be
# applied. The model is trained using mini-batch gradient descent. Evaluation is
# done using metrics such as Precision, Recall, F1-score, and ROC-AUC instead of
# accuracy, as accuracy is misleading for imbalanced datasets. Recall is
# especially important to minimize missed fraud cases.

# Optimizer and Overfitting Prevention:
# Adam optimizer is used because it provides adaptive learning rates and fast,
# stable convergence for large datasets. Overfitting is prevented using dropout
# layers, L2 regularization, early stopping, and proper train-validation split.

# Conclusion:
# A multilayer neural network with ReLU activation, sigmoid output layer, binary
# cross-entropy loss, and Adam optimizer is well suited for real-time fraud
# detection. Proper handling of class imbalance and regularization techniques
# ensures robust and reliable model performance.
